# %% [markdown]
# # Run CAMELS Training in Colab
#
# This notebook is only for Colab runtime setup and launching `train.py`.
# Data preparation is handled automatically by the training script.

# %%
import os
import sys

# %%
!"/Users/hwenzhang/OMSCS/courses/[7643]DL/.venv/bin/python" ./scripts/visualize_external_transformer_predictions.py \
  --model-type vanilla \
  --checkpoint ../CAMELS_data_load-xs-gpu_run/model_artifacts/raven_default/vanilla_transformer_best.pt
# Out:
# Reading joined table from: /Users/hwenzhang/OMSCS/courses/[7643]DL/Assignment/FP/CAMELS_data_load-xs-gpu_run/model_artifacts/raven_default/processed
# /Users/hwenzhang/OMSCS/courses/[7643]DL/.venv/lib/python3.9/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# vanilla TEST | RMSE=2.4273 MAE=0.6941 Global_NSE=0.5622 clipped_mean_basin_NSE=0.2838 clipped_median_basin_NSE=0.4036
# Saved prediction visualization to: /Users/hwenzhang/OMSCS/courses/[7643]DL/Assignment/FP/CAMELS_data_load-xs-gpu_run/model_artifacts/raven_default/figures/test_vanilla_predictions.png
# Saved single-basin time series to: /Users/hwenzhang/OMSCS/courses/[7643]DL/Assignment/FP/CAMELS_data_load-xs-gpu_run/model_artifacts/raven_default/figures/test_vanilla_predictions_basin_08190500.png
# ...

# %%
!"/Users/hwenzhang/OMSCS/courses/[7643]DL/.venv/bin/python" ./scripts/visualize_external_transformer_predictions.py \
  --model-type itransformer \
  --checkpoint ../CAMELS_data_load-itransformer/model_artifacts/itransformer_default/itransformer_best.pt
# Out:
# Reading joined table from: /Users/hwenzhang/OMSCS/courses/[7643]DL/Assignment/FP/CAMELS_data_load-itransformer/model_artifacts/itransformer_default/processed
# /Users/hwenzhang/OMSCS/courses/[7643]DL/.venv/lib/python3.9/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# itransformer TEST | RMSE=2.5288 MAE=0.7981 Global_NSE=0.5248 clipped_mean_basin_NSE=0.2362 clipped_median_basin_NSE=0.3153

# %%
!"/Users/hwenzhang/OMSCS/courses/[7643]DL/.venv/bin/python" scripts/visualize_tft_predictions.py --config config/train.json --n-basin-panels 3 --basin-slot 0
# Out:
# Saved CV training curve to: /Users/hwenzhang/OMSCS/courses/[7643]DL/Assignment/FP/CAMELS_data_load-main/outputs/simple_tft_global_nse/cv_training_curve.png
# Loaded checkpoint: /Users/hwenzhang/OMSCS/courses/[7643]DL/Assignment/FP/CAMELS_data_load-main/outputs/simple_tft_global_nse/best_model.pt
# Using device: mps
# Split: pre_holdout=239547 windows used for normalization | test=holdout=60390 windows | val=last_fold_val=47641 windows
# ...
# VAL performance | RMSE=2.1234 MAE=0.4267 R2=0.6394 NSE=0.6394 clipped_mean_basin_NSE=0.6652 clipped_median_basin_NSE=0.7805
# Saved prediction visualization to: /Users/hwenzhang/OMSCS/courses/[7643]DL/Assignment/FP/CAMELS_data_load-main/outputs/simple_tft_global_nse/val_tft_predictions.png
# Saved single-basin time series to: /Users/hwenzhang/OMSCS/courses/[7643]DL/Assignment/FP/CAMELS_data_load-main/outputs/simple_tft_global_nse/val_tft_predictions_basin_01013500.png
# ...

# %%
!"/Users/hwenzhang/OMSCS/courses/[7643]DL/.venv/bin/python" scripts/visualize_tft_predictions.py --config config/lstm_baseline.json --n-basin-panels 3 --basin-slot 0
# Out:
# Saved CV training curve to: /Users/hwenzhang/OMSCS/courses/[7643]DL/Assignment/FP/CAMELS_data_load-main/outputs/lstm_baseline/cv_training_curve.png
# Loaded checkpoint: /Users/hwenzhang/OMSCS/courses/[7643]DL/Assignment/FP/CAMELS_data_load-main/outputs/lstm_baseline/best_model.pt
# Using device: mps
# Split: pre_holdout=239547 windows used for normalization | test=holdout=60390 windows | val=last_fold_val=47641 windows
# ...
# VAL performance | RMSE=1.9942 MAE=0.3991 R2=0.6820 NSE=0.6820 clipped_mean_basin_NSE=0.6889 clipped_median_basin_NSE=0.7732
# Saved prediction visualization to: /Users/hwenzhang/OMSCS/courses/[7643]DL/Assignment/FP/CAMELS_data_load-main/outputs/lstm_baseline/val_tft_predictions.png
# Saved single-basin time series to: /Users/hwenzhang/OMSCS/courses/[7643]DL/Assignment/FP/CAMELS_data_load-main/outputs/lstm_baseline/val_tft_predictions_basin_01013500.png
# ...
