# %% [markdown]
# # Run CAMELS Training in Colab
#
# This notebook is only for Colab runtime setup and launching `train.py`.
# Data preparation is handled automatically by the training script.

# %%
# !pip install optuna
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Collecting optuna
#   Downloading optuna-4.8.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.49)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.11)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.8.0-py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 8.1 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.8.0
# Mounted at /content/drive

# %%
from pathlib import Path
import os
import sys

PROJECT_DIR = Path('/content/drive/MyDrive/DL/Project/CAMELS_data_load-main')
CONFIG_PATH = PROJECT_DIR / 'config' / 'lstm_baseline.json'

os.chdir(PROJECT_DIR)
print('Working directory:', Path.cwd())
print('Python executable:', sys.executable)
print('Config path:', CONFIG_PATH)
print('Config exists:', CONFIG_PATH.exists())
# Out:
# Working directory: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main
# Python executable: /usr/bin/python3
# Config path: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/config/lstm_baseline.json
# Config exists: True

# %%
import sys
# !{sys.executable} train.py --config config/lstm_baseline.json
# Out:
# Using existing prepared dataset: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/processed_with_qobs/camels_transformer_windows.npz
# Using device: cuda
# Loaded dataset from: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/processed_with_qobs/camels_transformer_windows.npz
# Model: lstm
# Training loss: GLOBAL_NSE
# Decoder future-known features: ['Dayl(s)', 'doy_sin', 'doy_cos']
# Static attributes (39): ['gauge_lat', 'gauge_lon', 'elev_mean', 'slope_mean', 'area_gages2', 'area_geospa_fabric', 'p_mean', 'pet_mean', 'p_seasonality', 'frac_snow', 'aridity', 'high_prec_freq', 'high_prec_dur', 'low_prec_freq', 'low_prec_dur', 'soil_depth_pelletier', 'soil_depth_statsgo', 'soil_porosity', 'soil_conductivity', 'max_water_content', 'sand_frac', 'silt_frac', 'clay_frac', 'water_frac', 'organic_frac', 'other_frac', 'frac_forest', 'lai_max', 'lai_diff', 'gvf_max', 'gvf_diff', 'dom_land_cover_frac', 'root_depth_50', 'root_depth_99', 'glim_1st_class_frac', 'glim_2nd_class_frac', 'carbonate_rocks_frac', 'geol_porostiy', 'geol_permeability']
# Dataset shapes: features=(8415489, 11), targets=(8415489,), windows=299937 features_per_step=11
# Split strategy: expanding_cv | pre-holdout=239547 holdout=60390 folds=4
#   Fold 0: per-basin expanding split | train=48312 val=48312 | train_basins=671 val_basins=671
#   Fold 1: per-basin expanding split | train=96624 val=47641 | train_basins=671 val_basins=671
#   Fold 2: per-basin expanding split | train=144265 val=47641 | train_basins=671 val_basins=671
#   Fold 3: per-basin expanding split | train=191906 val=47641 | train_basins=671 val_basins=671
# CV fold 0 Epoch 001 | train_loss=0.628190 train_nse=0.025670 train_global_nse=0.046104 | val_loss=0.426679 val_nse=0.290559 val_median_nse=0.549532 val_global_nse=0.445237
# CV fold 0 Epoch 002 | train_loss=0.340084 train_nse=0.255347 train_global_nse=0.023125 | val_loss=0.352204 val_nse=0.249820 val_median_nse=0.592650 val_global_nse=0.423662
# CV fold 0 Epoch 003 | train_loss=0.301303 train_nse=0.312236 train_global_nse=0.011523 | val_loss=0.325159 val_nse=0.445829 val_median_nse=0.651722 val_global_nse=0.516594
# CV fold 0 Epoch 004 | train_loss=0.277256 train_nse=0.460217 train_global_nse=0.089756 | val_loss=0.288229 val_nse=0.491735 val_median_nse=0.677199 val_global_nse=0.573610
# CV fold 0 Epoch 005 | train_loss=0.230500 train_nse=0.520935 train_global_nse=0.107646 | val_loss=0.278447 val_nse=0.499691 val_median_nse=0.674665 val_global_nse=0.595048
# CV fold 0 Epoch 006 | train_loss=0.220908 train_nse=0.554152 train_global_nse=0.124653 | val_loss=0.280126 val_nse=0.543720 val_median_nse=0.696557 val_global_nse=0.626253
# CV fold 0 Epoch 007 | train_loss=0.209062 train_nse=0.584403 train_global_nse=0.130340 | val_loss=0.251595 val_nse=0.511668 val_median_nse=0.699947 val_global_nse=0.621907
# CV fold 0 Epoch 008 | train_loss=0.199234 train_nse=0.613633 train_global_nse=0.137171 | val_loss=0.256530 val_nse=0.568721 val_median_nse=0.715770 val_global_nse=0.642379
# CV fold 0 Epoch 009 | train_loss=0.191186 train_nse=0.638159 train_global_nse=0.139098 | val_loss=0.243044 val_nse=0.579953 val_median_nse=0.703907 val_global_nse=0.633197
# CV fold 0 Epoch 010 | train_loss=0.184552 train_nse=0.651913 train_global_nse=0.143301 | val_loss=0.253884 val_nse=0.489860 val_median_nse=0.703847 val_global_nse=0.631639
# CV fold 1 Epoch 001 | train_loss=0.454059 train_nse=0.329445 train_global_nse=0.077387 | val_loss=0.333660 val_nse=0.435967 val_median_nse=0.547431 val_global_nse=-0.029038
# CV fold 1 Epoch 002 | train_loss=0.265023 train_nse=0.493437 train_global_nse=0.107122 | val_loss=0.288902 val_nse=0.467494 val_median_nse=0.595122 val_global_nse=0.076100
# CV fold 1 Epoch 003 | train_loss=0.233837 train_nse=0.560619 train_global_nse=0.166962 | val_loss=0.260834 val_nse=0.505328 val_median_nse=0.625093 val_global_nse=0.288854
# CV fold 1 Epoch 004 | train_loss=0.216744 train_nse=0.604776 train_global_nse=0.199114 | val_loss=0.252550 val_nse=0.563760 val_median_nse=0.676397 val_global_nse=0.433911
# CV fold 1 Epoch 005 | train_loss=0.194074 train_nse=0.629003 train_global_nse=0.207074 | val_loss=0.239529 val_nse=0.583347 val_median_nse=0.683108 val_global_nse=0.496299
# CV fold 1 Epoch 006 | train_loss=0.185670 train_nse=0.640537 train_global_nse=0.211734 | val_loss=0.238745 val_nse=0.614927 val_median_nse=0.701454 val_global_nse=0.576964
# CV fold 1 Epoch 007 | train_loss=0.177182 train_nse=0.650794 train_global_nse=0.213405 | val_loss=0.228712 val_nse=0.608445 val_median_nse=0.705112 val_global_nse=0.560682
# CV fold 1 Epoch 008 | train_loss=0.170676 train_nse=0.665131 train_global_nse=0.220023 | val_loss=0.224866 val_nse=0.615179 val_median_nse=0.708997 val_global_nse=0.580109
# CV fold 1 Epoch 009 | train_loss=0.165703 train_nse=0.673126 train_global_nse=0.220924 | val_loss=0.224937 val_nse=0.597363 val_median_nse=0.703781 val_global_nse=0.533344
# CV fold 1 Epoch 010 | train_loss=0.159256 train_nse=0.679593 train_global_nse=0.222429 | val_loss=0.221012 val_nse=0.598912 val_median_nse=0.705457 val_global_nse=0.536031
# CV fold 2 Epoch 001 | train_loss=0.394526 train_nse=0.313985 train_global_nse=-0.094933 | val_loss=0.301834 val_nse=0.460923 val_median_nse=0.625640 val_global_nse=0.285793
# CV fold 2 Epoch 002 | train_loss=0.248188 train_nse=0.521256 train_global_nse=0.173538 | val_loss=0.268214 val_nse=0.455383 val_median_nse=0.649484 val_global_nse=0.532599
# CV fold 2 Epoch 003 | train_loss=0.222368 train_nse=0.574288 train_global_nse=0.245707 | val_loss=0.225651 val_nse=0.565289 val_median_nse=0.729384 val_global_nse=0.616827
# CV fold 2 Epoch 004 | train_loss=0.207593 train_nse=0.606814 train_global_nse=0.274751 | val_loss=0.218804 val_nse=0.526737 val_median_nse=0.726044 val_global_nse=0.619316
# CV fold 2 Epoch 005 | train_loss=0.187552 train_nse=0.623840 train_global_nse=0.288018 | val_loss=0.206709 val_nse=0.566862 val_median_nse=0.738167 val_global_nse=0.633142
# CV fold 2 Epoch 006 | train_loss=0.179418 train_nse=0.635766 train_global_nse=0.293460 | val_loss=0.200394 val_nse=0.574719 val_median_nse=0.750351 val_global_nse=0.634608
# CV fold 2 Epoch 007 | train_loss=0.172558 train_nse=0.645061 train_global_nse=0.298483 | val_loss=0.210704 val_nse=0.544245 val_median_nse=0.742609 val_global_nse=0.630707
# CV fold 2 Epoch 008 | train_loss=0.168171 train_nse=0.653568 train_global_nse=0.301726 | val_loss=0.201297 val_nse=0.570570 val_median_nse=0.749087 val_global_nse=0.628616
# CV fold 2 Epoch 009 | train_loss=0.162844 train_nse=0.660013 train_global_nse=0.304267 | val_loss=0.200398 val_nse=0.507865 val_median_nse=0.751505 val_global_nse=0.630112
# CV fold 2 Epoch 010 | train_loss=0.157203 train_nse=0.671881 train_global_nse=0.309981 | val_loss=0.191465 val_nse=0.597244 val_median_nse=0.758616 val_global_nse=0.628923
# CV fold 3 Epoch 001 | train_loss=0.355443 train_nse=0.390240 train_global_nse=0.054044 | val_loss=0.289291 val_nse=0.527221 val_median_nse=0.634951 val_global_nse=0.513584
# CV fold 3 Epoch 002 | train_loss=0.232584 train_nse=0.543169 train_global_nse=0.230567 | val_loss=0.248753 val_nse=0.591617 val_median_nse=0.693267 val_global_nse=0.601354
# CV fold 3 Epoch 003 | train_loss=0.211428 train_nse=0.596256 train_global_nse=0.315092 | val_loss=0.223061 val_nse=0.636790 val_median_nse=0.726361 val_global_nse=0.613634
# CV fold 3 Epoch 004 | train_loss=0.198303 train_nse=0.605479 train_global_nse=0.310530 | val_loss=0.205138 val_nse=0.655239 val_median_nse=0.735265 val_global_nse=0.607028
# CV fold 3 Epoch 005 | train_loss=0.180662 train_nse=0.626277 train_global_nse=0.333527 | val_loss=0.205132 val_nse=0.650925 val_median_nse=0.745055 val_global_nse=0.626090
# CV fold 3 Epoch 006 | train_loss=0.173242 train_nse=0.638925 train_global_nse=0.341990 | val_loss=0.198057 val_nse=0.658726 val_median_nse=0.749086 val_global_nse=0.634170
# CV fold 3 Epoch 007 | train_loss=0.168127 train_nse=0.645912 train_global_nse=0.343556 | val_loss=0.203871 val_nse=0.637125 val_median_nse=0.744884 val_global_nse=0.631904
# CV fold 3 Epoch 008 | train_loss=0.162426 train_nse=0.653565 train_global_nse=0.346546 | val_loss=0.206878 val_nse=0.654962 val_median_nse=0.750724 val_global_nse=0.636456
# CV fold 3 Epoch 009 | train_loss=0.157867 train_nse=0.662456 train_global_nse=0.351974 | val_loss=0.197914 val_nse=0.661175 val_median_nse=0.758332 val_global_nse=0.640006
# CV fold 3 Epoch 010 | train_loss=0.155501 train_nse=0.668665 train_global_nse=0.350840 | val_loss=0.187148 val_nse=0.650080 val_median_nse=0.769870 val_global_nse=0.625414
# Final training epochs chosen from CV: 9
# Final Epoch 001 | train_loss=0.343420 train_nse=0.398560 train_global_nse=0.093494
# Final Epoch 002 | train_loss=0.225952 train_nse=0.554349 train_global_nse=0.303589
# Final Epoch 003 | train_loss=0.203831 train_nse=0.599552 train_global_nse=0.358456
# Final Epoch 004 | train_loss=0.192126 train_nse=0.621595 train_global_nse=0.370850
# Final Epoch 005 | train_loss=0.174042 train_nse=0.617951 train_global_nse=0.343829
# Final Epoch 006 | train_loss=0.167890 train_nse=0.639748 train_global_nse=0.377272
# Final Epoch 007 | train_loss=0.162030 train_nse=0.652178 train_global_nse=0.385882
# Final Epoch 008 | train_loss=0.157463 train_nse=0.661883 train_global_nse=0.385993
# Final Epoch 009 | train_loss=0.154010 train_nse=0.667680 train_global_nse=0.392694
# Expanding-CV holdout metrics | loss=0.202598 mae=1.351017 rmse=12.764569 mean_basin_nse=0.428851 median_basin_nse=0.503577 global_nse=0.060147

# %%
import sys
# !{sys.executable} train.py --config config/train.json
# Out:
# Using existing prepared dataset: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/processed_with_qobs/camels_transformer_windows.npz
# Using device: cuda
# Loaded dataset from: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/processed_with_qobs/camels_transformer_windows.npz
# Training loss: GLOBAL_NSE
# Decoder future-known features: ['Dayl(s)', 'doy_sin', 'doy_cos']
# Static attributes (39): ['gauge_lat', 'gauge_lon', 'elev_mean', 'slope_mean', 'area_gages2', 'area_geospa_fabric', 'p_mean', 'pet_mean', 'p_seasonality', 'frac_snow', 'aridity', 'high_prec_freq', 'high_prec_dur', 'low_prec_freq', 'low_prec_dur', 'soil_depth_pelletier', 'soil_depth_statsgo', 'soil_porosity', 'soil_conductivity', 'max_water_content', 'sand_frac', 'silt_frac', 'clay_frac', 'water_frac', 'organic_frac', 'other_frac', 'frac_forest', 'lai_max', 'lai_diff', 'gvf_max', 'gvf_diff', 'dom_land_cover_frac', 'root_depth_50', 'root_depth_99', 'glim_1st_class_frac', 'glim_2nd_class_frac', 'carbonate_rocks_frac', 'geol_porostiy', 'geol_permeability']
# Dataset shapes: features=(8415489, 11), targets=(8415489,), windows=299937 features_per_step=11
# Split strategy: expanding_cv | pre-holdout=239547 holdout=60390 folds=4
#   Fold 0: per-basin expanding split | train=48312 val=48312 | train_basins=671 val_basins=671
#   Fold 1: per-basin expanding split | train=96624 val=47641 | train_basins=671 val_basins=671
#   Fold 2: per-basin expanding split | train=144265 val=47641 | train_basins=671 val_basins=671
#   Fold 3: per-basin expanding split | train=191906 val=47641 | train_basins=671 val_basins=671
# CV fold 0 Epoch 001 | train_loss=0.505345 train_nse=0.288199 train_global_nse=0.100010 | val_loss=0.374528 val_nse=0.369603 val_median_nse=0.578906 val_global_nse=0.571957
# CV fold 0 Epoch 002 | train_loss=0.313086 train_nse=0.479220 train_global_nse=0.124199 | val_loss=0.353229 val_nse=0.406474 val_median_nse=0.594367 val_global_nse=0.608688
# CV fold 0 Epoch 003 | train_loss=0.272315 train_nse=0.579929 train_global_nse=0.131720 | val_loss=0.320323 val_nse=0.492433 val_median_nse=0.644712 val_global_nse=0.611513
# CV fold 0 Epoch 004 | train_loss=0.246964 train_nse=0.603043 train_global_nse=0.136574 | val_loss=0.292821 val_nse=0.438730 val_median_nse=0.634277 val_global_nse=0.604379
# CV fold 0 Epoch 005 | train_loss=0.201715 train_nse=0.634327 train_global_nse=0.140313 | val_loss=0.283381 val_nse=0.458011 val_median_nse=0.654072 val_global_nse=0.616818
# CV fold 1 Epoch 001 | train_loss=0.384028 train_nse=0.435369 train_global_nse=0.165775 | val_loss=0.304364 val_nse=0.549665 val_median_nse=0.587544 val_global_nse=0.555999
# CV fold 1 Epoch 002 | train_loss=0.241679 train_nse=0.581370 train_global_nse=0.198614 | val_loss=0.293560 val_nse=0.523452 val_median_nse=0.603394 val_global_nse=0.533305
# CV fold 1 Epoch 003 | train_loss=0.212403 train_nse=0.625779 train_global_nse=0.205004 | val_loss=0.266135 val_nse=0.559028 val_median_nse=0.632226 val_global_nse=0.586010
# CV fold 1 Epoch 004 | train_loss=0.196066 train_nse=0.639596 train_global_nse=0.213120 | val_loss=0.252269 val_nse=0.564210 val_median_nse=0.677972 val_global_nse=0.605626
# CV fold 1 Epoch 005 | train_loss=0.175709 train_nse=0.663798 train_global_nse=0.215388 | val_loss=0.240948 val_nse=0.595941 val_median_nse=0.674850 val_global_nse=0.606939
# CV fold 2 Epoch 001 | train_loss=0.351067 train_nse=0.459303 train_global_nse=0.232651 | val_loss=0.276527 val_nse=0.573317 val_median_nse=0.674628 val_global_nse=0.576468
# CV fold 2 Epoch 002 | train_loss=0.233382 train_nse=0.581295 train_global_nse=0.271888 | val_loss=0.273352 val_nse=0.447940 val_median_nse=0.614531 val_global_nse=0.585127
# CV fold 2 Epoch 003 | train_loss=0.211710 train_nse=0.608361 train_global_nse=0.282531 | val_loss=0.226803 val_nse=0.579469 val_median_nse=0.703910 val_global_nse=0.608418
# CV fold 2 Epoch 004 | train_loss=0.196639 train_nse=0.625361 train_global_nse=0.284329 | val_loss=0.219367 val_nse=0.568851 val_median_nse=0.722712 val_global_nse=0.614032
# CV fold 2 Epoch 005 | train_loss=0.178369 train_nse=0.640259 train_global_nse=0.293806 | val_loss=0.208613 val_nse=0.622450 val_median_nse=0.734674 val_global_nse=0.612794
# CV fold 3 Epoch 001 | train_loss=0.318935 train_nse=0.483339 train_global_nse=0.272128 | val_loss=0.233086 val_nse=0.621208 val_median_nse=0.689068 val_global_nse=0.559572
# CV fold 3 Epoch 002 | train_loss=0.214703 train_nse=0.591486 train_global_nse=0.319290 | val_loss=0.204485 val_nse=0.635226 val_median_nse=0.719341 val_global_nse=0.586780
# CV fold 3 Epoch 003 | train_loss=0.197342 train_nse=0.615710 train_global_nse=0.331499 | val_loss=0.224123 val_nse=0.485406 val_median_nse=0.622558 val_global_nse=0.575875
# CV fold 3 Epoch 004 | train_loss=0.187032 train_nse=0.633668 train_global_nse=0.336848 | val_loss=0.206243 val_nse=0.585050 val_median_nse=0.725673 val_global_nse=0.619918
# CV fold 3 Epoch 005 | train_loss=0.169721 train_nse=0.647379 train_global_nse=0.347005 | val_loss=0.199697 val_nse=0.605927 val_median_nse=0.733706 val_global_nse=0.632158
# Final training epochs chosen from CV: 5
# Final Epoch 001 | train_loss=0.306464 train_nse=0.492982 train_global_nse=0.310619
# Final Epoch 002 | train_loss=0.214214 train_nse=0.585462 train_global_nse=0.352184
# Final Epoch 003 | train_loss=0.193567 train_nse=0.614672 train_global_nse=0.365189
# Final Epoch 004 | train_loss=0.183020 train_nse=0.633718 train_global_nse=0.378746
# Final Epoch 005 | train_loss=0.165203 train_nse=0.650947 train_global_nse=0.384405
# Expanding-CV holdout metrics | loss=0.227979 mae=1.372196 rmse=12.809234 mean_basin_nse=0.245291 median_basin_nse=0.456292 global_nse=0.053558

# %%
import sys
# !{sys.executable} scripts/visualize_tft_predictions.py --config config/lstm_baseline.json --n-basin-panels 3 --basin-slot 0
# Out:
# Saved CV training curve to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/cv_training_curve.png
# Loaded checkpoint: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/best_model.pt
# Using device: cpu
# VAL performance | RMSE=2.0166 MAE=0.3956 R2=0.6947 NSE=0.6947 mean_basin_NSE=0.7314 median_basin_NSE=0.8209
# Saved prediction visualization to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/val_tft_predictions.png
# Saved single-basin time series to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/val_tft_predictions_basin_01013500.png
# Saved best/worst basin panels to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/val_tft_predictions_best_worst_basins.png
# Saved per-basin NSE distribution to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/val_tft_predictions_per_basin_nse_distribution.png
# Saved per-basin NSE + static attributes to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/val_tft_predictions_basin_static_attributes.csv
# Saved static attribute correlations to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/val_tft_predictions_static_attribute_correlations.csv
# Saved NSE vs static attribute plot to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/val_tft_predictions_nse_vs_static_attributes.png
# Saved per-basin NSE to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/val_tft_predictions_per_basin_nse.json
# TEST performance | RMSE=14.7210 MAE=1.6586 R2=0.0442 NSE=0.0442 mean_basin_NSE=0.4190 median_basin_NSE=0.4813
# Saved prediction visualization to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/test_tft_predictions.png
# Saved single-basin time series to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/test_tft_predictions_basin_01013500.png
# Saved best/worst basin panels to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/test_tft_predictions_best_worst_basins.png
# Saved per-basin NSE distribution to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/test_tft_predictions_per_basin_nse_distribution.png
# Saved per-basin NSE + static attributes to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/test_tft_predictions_basin_static_attributes.csv
# Saved static attribute correlations to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/test_tft_predictions_static_attribute_correlations.csv
# Saved NSE vs static attribute plot to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/test_tft_predictions_nse_vs_static_attributes.png
# Saved per-basin NSE to: /content/drive/MyDrive/DL/Project/CAMELS_data_load-main/outputs/lstm_baseline/test_tft_predictions_per_basin_nse.json
